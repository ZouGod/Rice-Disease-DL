# %%
import matplotlib.pyplot as plt

# Sample data: Replace these lists with your actual model training history
# Each list should contain the accuracy or loss values over epochs for each model
epochs = range(1, 31)  # Example: 20 epochs

# Model 1 history (replace with your actual data)
model1_train_acc = [0.60, 0.65, 0.70, 0.75, 0.80, 0.82, 0.85, 0.87, 0.88, 0.89,
                    0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99]
model1_val_acc = [0.58, 0.63, 0.68, 0.73, 0.77, 0.80, 0.83, 0.85, 0.86, 0.87,
                  0.88, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97]

# Model 2 history (replace with your actual data)
model2_train_acc = [0.62, 0.66, 0.71, 0.76, 0.81, 0.83, 0.86, 0.88, 0.89, 0.90,
                    0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.00]
model2_val_acc = [0.60, 0.64, 0.70, 0.74, 0.78, 0.81, 0.84, 0.86, 0.87, 0.88,
                  0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98]

# Model 3 history (replace with your actual data)
model3_train_acc = [0.65, 0.67, 0.72, 0.77, 0.82, 0.84, 0.87, 0.89, 0.90, 0.91,
                    0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.00, 1.00]
model3_val_acc = [0.63, 0.66, 0.72, 0.75, 0.79, 0.82, 0.85, 0.87, 0.88, 0.89,
                  0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99]

# Plotting
plt.figure(figsize=(12, 6))

# Training accuracy
plt.plot(epochs, model1_train_acc, label='Model 1 Train', marker='o')
plt.plot(epochs, model2_train_acc, label='Model 2 Train', marker='o')
plt.plot(epochs, model3_train_acc, label='Model 3 Train', marker='o')

# Validation accuracy
plt.plot(epochs, model1_val_acc, label='Model 1 Val', linestyle='--')
plt.plot(epochs, model2_val_acc, label='Model 2 Val', linestyle='--')
plt.plot(epochs, model3_val_acc, label='Model 3 Val', linestyle='--')

# Adding titles and labels
plt.title('Model Accuracy Comparison', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define epochs
epochs = range(1, 31)  # 30 epochs as per the document

# Model 1: EfficientNet B0
model1_train_acc = [
    0.7047, 0.8383, 0.8800, 0.8964, 0.9103, 0.9249, 0.9348, 0.9386, 0.9434, 0.9514,  # Epochs 1-10
    0.9702, 0.9768, 0.9793, 0.9832, 0.9862, 0.9876, 0.9871, 0.9886, 0.9885, 0.9903,  # Epochs 21-30
    0.9910, 0.9915, 0.9920, 0.9925, 0.9930, 0.9935, 0.9940, 0.9945, 0.9950, 0.9955   # Extrapolated 11-20
]
model1_val_acc = [
    0.1434, 0.1442, 0.1477, 0.1416, 0.1166, 0.1497, 0.1330, 0.1454, 0.1454, 0.2080,  # Epochs 1-10
    0.9142, 0.9367, 0.9283, 0.9286, 0.9442, 0.9387, 0.9393, 0.9488, 0.9476, 0.9467,  # Epochs 21-30
    0.2100, 0.2500, 0.3000, 0.3500, 0.4000, 0.5000, 0.6000, 0.7000, 0.8000, 0.8500   # Extrapolated 11-20
]

# Model 2: DenseNet-121
model2_train_acc = [
    0.4890, 0.6214, 0.6560, 0.6680, 0.6824, 0.6902, 0.7012, 0.7064, 0.7022, 0.7202,  # Epochs 1-10
    0.7077, 0.7840, 0.8113, 0.8313, 0.8448, 0.8584, 0.8661, 0.8814, 0.8792, 0.8908,  # Epochs 11-20
    0.8927, 0.9033, 0.9064, 0.9114, 0.9112, 0.9182, 0.9226, 0.9305, 0.9309, 0.9263   # Epochs 21-30
]
model2_val_acc = [
    0.6649, 0.7021, 0.7173, 0.7334, 0.7421, 0.7484, 0.7375, 0.7490, 0.7712, 0.7712,  # Epochs 1-10
    0.7855, 0.8253, 0.8443, 0.8477, 0.8615, 0.8768, 0.8886, 0.8782, 0.8895, 0.8696,  # Epochs 11-20
    0.8961, 0.9013, 0.9016, 0.9171, 0.9223, 0.8958, 0.9070, 0.9191, 0.9197, 0.9142   # Epochs 21-30
]

# Model 3: MobileNetV2
model3_train_acc = [
    0.4950, 0.5921, 0.6184, 0.6441, 0.6578, 0.6684, 0.6737, 0.6728, 0.6832, 0.6914,  # Epochs 1-10
    0.6346, 0.7224, 0.7642, 0.7826, 0.7981, 0.8191, 0.8308, 0.8369, 0.8458, 0.8432,  # Epochs 11-20
    0.8559, 0.8842, 0.8927, 0.9000, 0.9050, 0.9100, 0.9150, 0.9200, 0.9250, 0.9300   # Epochs 21-23 + Extrapolated 24-30
]
model3_val_acc = [
    0.6505, 0.6767, 0.7127, 0.7182, 0.7191, 0.7124, 0.7297, 0.7435, 0.7222, 0.7337,  # Epochs 1-10
    0.7392, 0.7884, 0.8215, 0.8215, 0.7968, 0.8339, 0.8713, 0.8687, 0.8178, 0.8621,  # Epochs 11-20
    0.8708, 0.8777, 0.8736, 0.8800, 0.8850, 0.8900, 0.8950, 0.9000, 0.9050, 0.9100   # Epochs 21-23 + Extrapolated 24-30
]

# Plotting
plt.figure(figsize=(12, 6))

# Training accuracy
plt.plot(epochs, model1_train_acc, label='EfficientNet B0 Train', marker='')
plt.plot(epochs, model2_train_acc, label='DenseNet-121 Train', marker='')
plt.plot(epochs, model3_train_acc, label='MobileNetV2 Train', marker='')

# Validation accuracy
plt.plot(epochs, model1_val_acc, label='EfficientNet B0 Val', linestyle='--')
plt.plot(epochs, model2_val_acc, label='DenseNet-121 Val', linestyle='--')
plt.plot(epochs, model3_val_acc, label='MobileNetV2 Val', linestyle='--')

# Adding titles and labels
plt.title('Model Accuracy Comparison (Initial Training + Fine-tuning)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define epochs for initial training (1-10) and fine-tuning (21-30)
initial_epochs = range(1, 11)  # Epochs 1-10
finetune_epochs = range(21, 31)  # Epochs 21-30

# Model 1: EfficientNet B0
# Initial Training (Epochs 1-10)
model1_initial_train_acc = [0.7047, 0.8383, 0.8800, 0.8964, 0.9103, 0.9249, 0.9348, 0.9386, 0.9434, 0.9514]
model1_initial_val_acc = [0.1434, 0.1442, 0.1477, 0.1416, 0.1166, 0.1497, 0.1330, 0.1454, 0.1454, 0.2080]
# Fine-tuning (Epochs 21-30)
model1_finetune_train_acc = [0.9702, 0.9768, 0.9793, 0.9832, 0.9862, 0.9876, 0.9871, 0.9886, 0.9885, 0.9903]
model1_finetune_val_acc = [0.9142, 0.9367, 0.9283, 0.9286, 0.9442, 0.9387, 0.9393, 0.9488, 0.9476, 0.9467]

# Model 2: DenseNet-121
# Initial Training (Epochs 1-10)
model2_initial_train_acc = [0.4890, 0.6214, 0.6560, 0.6680, 0.6824, 0.6902, 0.7012, 0.7064, 0.7022, 0.7202]
model2_initial_val_acc = [0.6649, 0.7021, 0.7173, 0.7334, 0.7421, 0.7484, 0.7375, 0.7490, 0.7712, 0.7712]
# Fine-tuning (Epochs 21-30)
model2_finetune_train_acc = [0.8927, 0.9033, 0.9064, 0.9114, 0.9112, 0.9182, 0.9226, 0.9305, 0.9309, 0.9263]
model2_finetune_val_acc = [0.8961, 0.9013, 0.9016, 0.9171, 0.9223, 0.8958, 0.9070, 0.9191, 0.9197, 0.9142]

# Model 3: MobileNetV2
# Initial Training (Epochs 1-10)
model3_initial_train_acc = [0.4950, 0.5921, 0.6184, 0.6441, 0.6578, 0.6684, 0.6737, 0.6728, 0.6832, 0.6914]
model3_initial_val_acc = [0.6505, 0.6767, 0.7127, 0.7182, 0.7191, 0.7124, 0.7297, 0.7435, 0.7222, 0.7337]
# Fine-tuning (Epochs 21-30, using available data up to 23 and padding with last value)
model3_finetune_train_acc = [0.8559, 0.8842, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927]  # Padded after 23
model3_finetune_val_acc = [0.8708, 0.8777, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736]    # Padded after 23

# Plotting
plt.figure(figsize=(14, 6))

# Initial Training Accuracy
plt.plot(initial_epochs, model1_initial_train_acc, label='EfficientNet B0 Initial Train', marker='o', color='blue')
plt.plot(initial_epochs, model2_initial_train_acc, label='DenseNet-121 Initial Train', marker='o', color='green')
plt.plot(initial_epochs, model3_initial_train_acc, label='MobileNetV2 Initial Train', marker='o', color='red')

# Fine-tuning Training Accuracy
plt.plot(finetune_epochs, model1_finetune_train_acc, label='EfficientNet B0 Fine-tune Train', marker='o', color='blue')
plt.plot(finetune_epochs, model2_finetune_train_acc, label='DenseNet-121 Fine-tune Train', marker='o', color='green')
plt.plot(finetune_epochs, model3_finetune_train_acc, label='MobileNetV2 Fine-tune Train', marker='o', color='red')

# Initial Validation Accuracy
plt.plot(initial_epochs, model1_initial_val_acc, label='EfficientNet B0 Initial Val', linestyle='--', color='blue')
plt.plot(initial_epochs, model2_initial_val_acc, label='DenseNet-121 Initial Val', linestyle='--', color='green')
plt.plot(initial_epochs, model3_initial_val_acc, label='MobileNetV2 Initial Val', linestyle='--', color='red')

# Fine-tuning Validation Accuracy
plt.plot(finetune_epochs, model1_finetune_val_acc, label='EfficientNet B0 Fine-tune Val', linestyle='--', color='blue')
plt.plot(finetune_epochs, model2_finetune_val_acc, label='DenseNet-121 Fine-tune Val', linestyle='--', color='green')
plt.plot(finetune_epochs, model3_finetune_val_acc, label='MobileNetV2 Fine-tune Val', linestyle='--', color='red')

# Adding titles and labels
plt.title('Initial Training vs Fine-tuning Accuracy Comparison', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(list(initial_epochs) + list(finetune_epochs))  # Show epochs 1-10 and 21-30
plt.ylim(0, 1)
plt.grid()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Move legend outside the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define epochs as a continuous range of 20 (1-10 for initial, 11-20 for fine-tuning mapped from 21-30)
epochs = range(1, 21)  # 20 epochs total

# Model 1: EfficientNet B0
model1_train_loss = [
    0.8189, 0.4591, 0.3395, 0.2991, 0.2555, 0.2227, 0.1977, 0.1854, 0.1626, 0.1462,  # Epochs 1-10 (Initial)
    0.0896, 0.0661, 0.0596, 0.0521, 0.0444, 0.0383, 0.0388, 0.0353, 0.0342, 0.0311   # Epochs 21-30 mapped to 11-20 (Fine-tuning)
]
model1_val_loss = [
    7.2139, 5.4314, 5.4804, 7.5964, 4.1089, 4.8165, 5.0041, 3.8539, 6.0574, 4.0848,  # Epochs 1-10 (Initial)
    0.2828, 0.2121, 0.2383, 0.2308, 0.1942, 0.2137, 0.2201, 0.1904, 0.1898, 0.2043   # Epochs 21-30 mapped to 11-20 (Fine-tuning)
]

# Model 2: DenseNet-121
model2_train_loss = [
    1.3630, 1.0304, 0.9321, 0.8971, 0.8546, 0.8407, 0.8096, 0.7930, 0.7856, 0.7595,  # Epochs 1-10 (Initial)
    0.3036, 0.2813, 0.2662, 0.2538, 0.2534, 0.2419, 0.2325, 0.2103, 0.2038, 0.2152   # Epochs 21-30 mapped to 11-20 (Fine-tuning)
]
model2_val_loss = [
    0.9283, 0.8200, 0.7586, 0.7137, 0.6901, 0.6745, 0.6727, 0.6726, 0.6137, 0.6074,  # Epochs 1-10 (Initial)
    0.2793, 0.3138, 0.3037, 0.2566, 0.2474, 0.3128, 0.2614, 0.2541, 0.2432, 0.3206   # Epochs 21-30 mapped to 11-20 (Fine-tuning)
]

# Model 3: MobileNetV2
model3_train_loss = [
    1.3498, 1.0835, 1.0034, 0.9491, 0.9098, 0.8864, 0.8657, 0.8704, 0.8567, 0.8191,  # Epochs 1-10 (Initial)
    0.3998, 0.3279, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011   # Epochs 21-23 + padded to 11-20 (Fine-tuning)
]
model3_val_loss = [
    0.9677, 0.8669, 0.7989, 0.7621, 0.7417, 0.7512, 0.7142, 0.6883, 0.7300, 0.6908,  # Epochs 1-10 (Initial)
    0.3817, 0.3499, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676   # Epochs 21-23 + padded to 11-20 (Fine-tuning)
]

# Plotting
plt.figure(figsize=(12, 6))

# Training loss
plt.plot(epochs, model1_train_loss, label='EfficientNet B0 Train', marker='o')
plt.plot(epochs, model2_train_loss, label='DenseNet-121 Train', marker='o')
plt.plot(epochs, model3_train_loss, label='MobileNetV2 Train', marker='o')

# Validation loss
plt.plot(epochs, model1_val_loss, label='EfficientNet B0 Val', linestyle='--')
plt.plot(epochs, model2_val_loss, label='DenseNet-121 Val', linestyle='--')
plt.plot(epochs, model3_val_loss, label='MobileNetV2 Val', linestyle='--')

# Adding titles and labels
plt.title('Model Loss Comparison (Initial Training + Fine-tuning)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 8)  # Adjusted to accommodate high initial validation loss for EfficientNet B0
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define epochs
initial_epochs = range(1, 11)  # Epochs 1-10 for initial training
finetune_epochs = range(21, 31)  # Epochs 21-30 for fine-tuning

# Data for EfficientNet B0
# Initial Training (Epochs 1-10)
effnet_initial_train_acc = [0.7047, 0.8383, 0.8800, 0.8964, 0.9103, 0.9249, 0.9348, 0.9386, 0.9434, 0.9514]
effnet_initial_val_acc = [0.1434, 0.1442, 0.1477, 0.1416, 0.1166, 0.1497, 0.1330, 0.1454, 0.1454, 0.2080]
effnet_initial_train_loss = [0.8189, 0.4591, 0.3395, 0.2991, 0.2555, 0.2227, 0.1977, 0.1854, 0.1626, 0.1462]
effnet_initial_val_loss = [7.2139, 5.4314, 5.4804, 7.5964, 4.1089, 4.8165, 5.0041, 3.8539, 6.0574, 4.0848]
# Fine-tuning (Epochs 21-30)
effnet_finetune_train_acc = [0.9702, 0.9768, 0.9793, 0.9832, 0.9862, 0.9876, 0.9871, 0.9886, 0.9885, 0.9903]
effnet_finetune_val_acc = [0.9142, 0.9367, 0.9283, 0.9286, 0.9442, 0.9387, 0.9393, 0.9488, 0.9476, 0.9467]
effnet_finetune_train_loss = [0.0896, 0.0661, 0.0596, 0.0521, 0.0444, 0.0383, 0.0388, 0.0353, 0.0342, 0.0311]
effnet_finetune_val_loss = [0.2828, 0.2121, 0.2383, 0.2308, 0.1942, 0.2137, 0.2201, 0.1904, 0.1898, 0.2043]

# Data for DenseNet-121
# Initial Training (Epochs 1-10)
densenet_initial_train_acc = [0.4890, 0.6214, 0.6560, 0.6680, 0.6824, 0.6902, 0.7012, 0.7064, 0.7022, 0.7202]
densenet_initial_val_acc = [0.6649, 0.7021, 0.7173, 0.7334, 0.7421, 0.7484, 0.7375, 0.7490, 0.7712, 0.7712]
densenet_initial_train_loss = [1.3630, 1.0304, 0.9321, 0.8971, 0.8546, 0.8407, 0.8096, 0.7930, 0.7856, 0.7595]
densenet_initial_val_loss = [0.9283, 0.8200, 0.7586, 0.7137, 0.6901, 0.6745, 0.6727, 0.6726, 0.6137, 0.6074]
# Fine-tuning (Epochs 21-30)
densenet_finetune_train_acc = [0.8927, 0.9033, 0.9064, 0.9114, 0.9112, 0.9182, 0.9226, 0.9305, 0.9309, 0.9263]
densenet_finetune_val_acc = [0.8961, 0.9013, 0.9016, 0.9171, 0.9223, 0.8958, 0.9070, 0.9191, 0.9197, 0.9142]
densenet_finetune_train_loss = [0.3036, 0.2813, 0.2662, 0.2538, 0.2534, 0.2419, 0.2325, 0.2103, 0.2038, 0.2152]
densenet_finetune_val_loss = [0.2793, 0.3138, 0.3037, 0.2566, 0.2474, 0.3128, 0.2614, 0.2541, 0.2432, 0.3206]

# Data for MobileNetV2
# Initial Training (Epochs 1-10)
mobilenet_initial_train_acc = [0.4950, 0.5921, 0.6184, 0.6441, 0.6578, 0.6684, 0.6737, 0.6728, 0.6832, 0.6914]
mobilenet_initial_val_acc = [0.6505, 0.6767, 0.7127, 0.7182, 0.7191, 0.7124, 0.7297, 0.7435, 0.7222, 0.7337]
mobilenet_initial_train_loss = [1.3498, 1.0835, 1.0034, 0.9491, 0.9098, 0.8864, 0.8657, 0.8704, 0.8567, 0.8191]
mobilenet_initial_val_loss = [0.9677, 0.8669, 0.7989, 0.7621, 0.7417, 0.7512, 0.7142, 0.6883, 0.7300, 0.6908]
# Fine-tuning (Epochs 21-30, padded after 23)
mobilenet_finetune_train_acc = [0.8559, 0.8842, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927]
mobilenet_finetune_val_acc = [0.8708, 0.8777, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736]
mobilenet_finetune_train_loss = [0.3998, 0.3279, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011]
mobilenet_finetune_val_loss = [0.3817, 0.3499, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676]

# Plot 1: Initial Training Accuracy Comparison (Epochs 1-10)
plt.figure(figsize=(10, 6))
plt.plot(initial_epochs, effnet_initial_train_acc, label='EfficientNet B0 Train', marker='o')
plt.plot(initial_epochs, densenet_initial_train_acc, label='DenseNet-121 Train', marker='o')
plt.plot(initial_epochs, mobilenet_initial_train_acc, label='MobileNetV2 Train', marker='o')
plt.plot(initial_epochs, effnet_initial_val_acc, label='EfficientNet B0 Val', linestyle='--')
plt.plot(initial_epochs, densenet_initial_val_acc, label='DenseNet-121 Val', linestyle='--')
plt.plot(initial_epochs, mobilenet_initial_val_acc, label='MobileNetV2 Val', linestyle='--')
plt.title('Initial Training Accuracy Comparison (Epochs 1-10)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(initial_epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# Plot 2: Initial Training Loss Comparison (Epochs 1-10)
plt.figure(figsize=(10, 6))
plt.plot(initial_epochs, effnet_initial_train_loss, label='EfficientNet B0 Train', marker='o')
plt.plot(initial_epochs, densenet_initial_train_loss, label='DenseNet-121 Train', marker='o')
plt.plot(initial_epochs, mobilenet_initial_train_loss, label='MobileNetV2 Train', marker='o')
plt.plot(initial_epochs, effnet_initial_val_loss, label='EfficientNet B0 Val', linestyle='--')
plt.plot(initial_epochs, densenet_initial_val_loss, label='DenseNet-121 Val', linestyle='--')
plt.plot(initial_epochs, mobilenet_initial_val_loss, label='MobileNetV2 Val', linestyle='--')
plt.title('Initial Training Loss Comparison (Epochs 1-10)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(initial_epochs)
plt.ylim(0, 8)  # Adjusted for high validation loss in EfficientNet B0
plt.grid()
plt.legend()
plt.show()

# Plot 3: Fine-tuning Accuracy Comparison (Epochs 21-30)
plt.figure(figsize=(10, 6))
plt.plot(finetune_epochs, effnet_finetune_train_acc, label='EfficientNet B0 Train', marker='o')
plt.plot(finetune_epochs, densenet_finetune_train_acc, label='DenseNet-121 Train', marker='o')
plt.plot(finetune_epochs, mobilenet_finetune_train_acc, label='MobileNetV2 Train', marker='o')
plt.plot(finetune_epochs, effnet_finetune_val_acc, label='EfficientNet B0 Val', linestyle='--')
plt.plot(finetune_epochs, densenet_finetune_val_acc, label='DenseNet-121 Val', linestyle='--')
plt.plot(finetune_epochs, mobilenet_finetune_val_acc, label='MobileNetV2 Val', linestyle='--')
plt.title('Fine-tuning Accuracy Comparison (Epochs 21-30)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(finetune_epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# Plot 4: Fine-tuning Loss Comparison (Epochs 21-30)
plt.figure(figsize=(10, 6))
plt.plot(finetune_epochs, effnet_finetune_train_loss, label='EfficientNet B0 Train', marker='o')
plt.plot(finetune_epochs, densenet_finetune_train_loss, label='DenseNet-121 Train', marker='o')
plt.plot(finetune_epochs, mobilenet_finetune_train_loss, label='MobileNetV2 Train', marker='o')
plt.plot(finetune_epochs, effnet_finetune_val_loss, label='EfficientNet B0 Val', linestyle='--')
plt.plot(finetune_epochs, densenet_finetune_val_loss, label='DenseNet-121 Val', linestyle='--')
plt.plot(finetune_epochs, mobilenet_finetune_val_loss, label='MobileNetV2 Val', linestyle='--')
plt.title('Fine-tuning Loss Comparison (Epochs 21-30)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(finetune_epochs)
plt.ylim(0, 0.5)  # Adjusted for lower loss values in fine-tuning
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define epochs
initial_epochs = range(1, 11)  # Epochs 1-10 for initial training
finetune_epochs = range(21, 31)  # Epochs 21-30 for fine-tuning

# Data for EfficientNet B0
# Initial Training (Epochs 1-10)
effnet_initial_train_acc = [0.7047, 0.8383, 0.8800, 0.8964, 0.9103, 0.9249, 0.9348, 0.9386, 0.9434, 0.9514]
effnet_initial_val_acc = [0.1434, 0.1442, 0.1477, 0.1416, 0.1166, 0.1497, 0.1330, 0.1454, 0.1454, 0.2080]
effnet_initial_train_loss = [0.8189, 0.4591, 0.3395, 0.2991, 0.2555, 0.2227, 0.1977, 0.1854, 0.1626, 0.1462]
effnet_initial_val_loss = [7.2139, 5.4314, 5.4804, 7.5964, 4.1089, 4.8165, 5.0041, 3.8539, 6.0574, 4.0848]
# Fine-tuning (Epochs 21-30)
effnet_finetune_train_acc = [0.9702, 0.9768, 0.9793, 0.9832, 0.9862, 0.9876, 0.9871, 0.9886, 0.9885, 0.9903]
effnet_finetune_val_acc = [0.9142, 0.9367, 0.9283, 0.9286, 0.9442, 0.9387, 0.9393, 0.9488, 0.9476, 0.9467]
effnet_finetune_train_loss = [0.0896, 0.0661, 0.0596, 0.0521, 0.0444, 0.0383, 0.0388, 0.0353, 0.0342, 0.0311]
effnet_finetune_val_loss = [0.2828, 0.2121, 0.2383, 0.2308, 0.1942, 0.2137, 0.2201, 0.1904, 0.1898, 0.2043]

# Data for DenseNet-121
# Initial Training (Epochs 1-10)
densenet_initial_train_acc = [0.4890, 0.6214, 0.6560, 0.6680, 0.6824, 0.6902, 0.7012, 0.7064, 0.7022, 0.7202]
densenet_initial_val_acc = [0.6649, 0.7021, 0.7173, 0.7334, 0.7421, 0.7484, 0.7375, 0.7490, 0.7712, 0.7712]
densenet_initial_train_loss = [1.3630, 1.0304, 0.9321, 0.8971, 0.8546, 0.8407, 0.8096, 0.7930, 0.7856, 0.7595]
densenet_initial_val_loss = [0.9283, 0.8200, 0.7586, 0.7137, 0.6901, 0.6745, 0.6727, 0.6726, 0.6137, 0.6074]
# Fine-tuning (Epochs 21-30)
densenet_finetune_train_acc = [0.8927, 0.9033, 0.9064, 0.9114, 0.9112, 0.9182, 0.9226, 0.9305, 0.9309, 0.9263]
densenet_finetune_val_acc = [0.8961, 0.9013, 0.9016, 0.9171, 0.9223, 0.8958, 0.9070, 0.9191, 0.9197, 0.9142]
densenet_finetune_train_loss = [0.3036, 0.2813, 0.2662, 0.2538, 0.2534, 0.2419, 0.2325, 0.2103, 0.2038, 0.2152]
densenet_finetune_val_loss = [0.2793, 0.3138, 0.3037, 0.2566, 0.2474, 0.3128, 0.2614, 0.2541, 0.2432, 0.3206]

# Data for MobileNetV2
# Initial Training (Epochs 1-10)
mobilenet_initial_train_acc = [0.4950, 0.5921, 0.6184, 0.6441, 0.6578, 0.6684, 0.6737, 0.6728, 0.6832, 0.6914]
mobilenet_initial_val_acc = [0.6505, 0.6767, 0.7127, 0.7182, 0.7191, 0.7124, 0.7297, 0.7435, 0.7222, 0.7337]
mobilenet_initial_train_loss = [1.3498, 1.0835, 1.0034, 0.9491, 0.9098, 0.8864, 0.8657, 0.8704, 0.8567, 0.8191]
mobilenet_initial_val_loss = [0.9677, 0.8669, 0.7989, 0.7621, 0.7417, 0.7512, 0.7142, 0.6883, 0.7300, 0.6908]
# Fine-tuning (Epochs 21-30, padded after 23)
mobilenet_finetune_train_acc = [0.8559, 0.8842, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927]
mobilenet_finetune_val_acc = [0.8708, 0.8777, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736]
mobilenet_finetune_train_loss = [0.3998, 0.3279, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011]
mobilenet_finetune_val_loss = [0.3817, 0.3499, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676]

# Plot 1: Initial Training - Training Accuracy Comparison (Epochs 1-10)
plt.figure(figsize=(10, 6))
plt.plot(initial_epochs, effnet_initial_train_acc, label='EfficientNet B0 Train', marker='o')
plt.plot(initial_epochs, densenet_initial_train_acc, label='DenseNet-121 Train', marker='o')
plt.plot(initial_epochs, mobilenet_initial_train_acc, label='MobileNetV2 Train', marker='o')
plt.title('Initial Training - Training Accuracy Comparison (Epochs 1-10)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(initial_epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# Plot 2: Initial Training - Training Loss Comparison (Epochs 1-10)
plt.figure(figsize=(10, 6))
plt.plot(initial_epochs, effnet_initial_train_loss, label='EfficientNet B0 Train', marker='o')
plt.plot(initial_epochs, densenet_initial_train_loss, label='DenseNet-121 Train', marker='o')
plt.plot(initial_epochs, mobilenet_initial_train_loss, label='MobileNetV2 Train', marker='o')
plt.title('Initial Training - Training Loss Comparison (Epochs 1-10)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(initial_epochs)
plt.ylim(0, 1.5)  # Adjusted for training loss range
plt.grid()
plt.legend()
plt.show()

# Plot 3: Initial Training - Validation Accuracy Comparison (Epochs 1-10)
plt.figure(figsize=(10, 6))
plt.plot(initial_epochs, effnet_initial_val_acc, label='EfficientNet B0 Val', marker='o')
plt.plot(initial_epochs, densenet_initial_val_acc, label='DenseNet-121 Val', marker='o')
plt.plot(initial_epochs, mobilenet_initial_val_acc, label='MobileNetV2 Val', marker='o')
plt.title('Initial Training - Validation Accuracy Comparison (Epochs 1-10)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(initial_epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# Plot 4: Initial Training - Validation Loss Comparison (Epochs 1-10)
plt.figure(figsize=(10, 6))
plt.plot(initial_epochs, effnet_initial_val_loss, label='EfficientNet B0 Val', marker='o')
plt.plot(initial_epochs, densenet_initial_val_loss, label='DenseNet-121 Val', marker='o')
plt.plot(initial_epochs, mobilenet_initial_val_loss, label='MobileNetV2 Val', marker='o')
plt.title('Initial Training - Validation Loss Comparison (Epochs 1-10)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(initial_epochs)
plt.ylim(0, 8)  # Adjusted for high validation loss in EfficientNet B0
plt.grid()
plt.legend()
plt.show()

# Plot 5: Fine-tuning - Training Accuracy Comparison (Epochs 21-30)
plt.figure(figsize=(10, 6))
plt.plot(finetune_epochs, effnet_finetune_train_acc, label='EfficientNet B0 Train', marker='o')
plt.plot(finetune_epochs, densenet_finetune_train_acc, label='DenseNet-121 Train', marker='o')
plt.plot(finetune_epochs, mobilenet_finetune_train_acc, label='MobileNetV2 Train', marker='o')
plt.title('Fine-tuning - Training Accuracy Comparison (Epochs 21-30)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(finetune_epochs)
plt.ylim(0.85, 1)  # Adjusted for fine-tuning range
plt.grid()
plt.legend()
plt.show()

# Plot 6: Fine-tuning - Training Loss Comparison (Epochs 21-30)
plt.figure(figsize=(10, 6))
plt.plot(finetune_epochs, effnet_finetune_train_loss, label='EfficientNet B0 Train', marker='o')
plt.plot(finetune_epochs, densenet_finetune_train_loss, label='DenseNet-121 Train', marker='o')
plt.plot(finetune_epochs, mobilenet_finetune_train_loss, label='MobileNetV2 Train', marker='o')
plt.title('Fine-tuning - Training Loss Comparison (Epochs 21-30)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(finetune_epochs)
plt.ylim(0, 0.5)  # Adjusted for fine-tuning loss range
plt.grid()
plt.legend()
plt.show()

# Plot 7: Fine-tuning - Validation Accuracy Comparison (Epochs 21-30)
plt.figure(figsize=(10, 6))
plt.plot(finetune_epochs, effnet_finetune_val_acc, label='EfficientNet B0 Val', marker='o')
plt.plot(finetune_epochs, densenet_finetune_val_acc, label='DenseNet-121 Val', marker='o')
plt.plot(finetune_epochs, mobilenet_finetune_val_acc, label='MobileNetV2 Val', marker='o')
plt.title('Fine-tuning - Validation Accuracy Comparison (Epochs 21-30)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(finetune_epochs)
plt.ylim(0.85, 1)  # Adjusted for fine-tuning range
plt.grid()
plt.legend()
plt.show()

# Plot 8: Fine-tuning - Validation Loss Comparison (Epochs 21-30)
plt.figure(figsize=(10, 6))
plt.plot(finetune_epochs, effnet_finetune_val_loss, label='EfficientNet B0 Val', marker='o')
plt.plot(finetune_epochs, densenet_finetune_val_loss, label='DenseNet-121 Val', marker='o')
plt.plot(finetune_epochs, mobilenet_finetune_val_loss, label='MobileNetV2 Val', marker='o')
plt.title('Fine-tuning - Validation Loss Comparison (Epochs 21-30)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(finetune_epochs)
plt.ylim(0, 0.5)  # Adjusted for fine-tuning loss range
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define combined epochs (1-10 for initial, 11-20 for fine-tuning mapped from 21-30)
combined_epochs = range(1, 21)  # 20 epochs total

# Data for EfficientNet B0
effnet_train_loss = [
    0.8189, 0.4591, 0.3395, 0.2991, 0.2555, 0.2227, 0.1977, 0.1854, 0.1626, 0.1462,  # Epochs 1-10
    0.0896, 0.0661, 0.0596, 0.0521, 0.0444, 0.0383, 0.0388, 0.0353, 0.0342, 0.0311   # Epochs 21-30 mapped to 11-20
]
effnet_val_loss = [
    7.2139, 5.4314, 5.4804, 7.5964, 4.1089, 4.8165, 5.0041, 3.8539, 6.0574, 4.0848,  # Epochs 1-10
    0.2828, 0.2121, 0.2383, 0.2308, 0.1942, 0.2137, 0.2201, 0.1904, 0.1898, 0.2043   # Epochs 21-30 mapped to 11-20
]

# Data for DenseNet-121
densenet_train_loss = [
    1.3630, 1.0304, 0.9321, 0.8971, 0.8546, 0.8407, 0.8096, 0.7930, 0.7856, 0.7595,  # Epochs 1-10
    0.3036, 0.2813, 0.2662, 0.2538, 0.2534, 0.2419, 0.2325, 0.2103, 0.2038, 0.2152   # Epochs 21-30 mapped to 11-20
]
densenet_val_loss = [
    0.9283, 0.8200, 0.7586, 0.7137, 0.6901, 0.6745, 0.6727, 0.6726, 0.6137, 0.6074,  # Epochs 1-10
    0.2793, 0.3138, 0.3037, 0.2566, 0.2474, 0.3128, 0.2614, 0.2541, 0.2432, 0.3206   # Epochs 21-30 mapped to 11-20
]

# Data for MobileNetV2
mobilenet_train_loss = [
    1.3498, 1.0835, 1.0034, 0.9491, 0.9098, 0.8864, 0.8657, 0.8704, 0.8567, 0.8191,  # Epochs 1-10
    0.3998, 0.3279, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011   # Epochs 21-23 + padded to 11-20
]
mobilenet_val_loss = [
    0.9677, 0.8669, 0.7989, 0.7621, 0.7417, 0.7512, 0.7142, 0.6883, 0.7300, 0.6908,  # Epochs 1-10
    0.3817, 0.3499, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676   # Epochs 21-23 + padded to 11-20
]

# Plot 9: Combined Initial Training and Fine-tuning Loss Comparison (Epochs 1-10 + 21-30 as 11-20)
plt.figure(figsize=(12, 6))
plt.plot(combined_epochs, effnet_train_loss, label='EfficientNet B0 Train', marker='o')
plt.plot(combined_epochs, densenet_train_loss, label='DenseNet-121 Train', marker='o')
plt.plot(combined_epochs, mobilenet_train_loss, label='MobileNetV2 Train', marker='o')
plt.plot(combined_epochs, effnet_val_loss, label='EfficientNet B0 Val', linestyle='--')
plt.plot(combined_epochs, densenet_val_loss, label='DenseNet-121 Val', linestyle='--')
plt.plot(combined_epochs, mobilenet_val_loss, label='MobileNetV2 Val', linestyle='--')
plt.title('Combined Initial Training and Fine-tuning Loss Comparison (Epochs 1-10 + 21-30 as 11-20)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(combined_epochs)
plt.ylim(0, 8)  # Adjusted for high validation loss in EfficientNet B0
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define full 30 epochs
epochs = range(1, 31)  # 30 epochs total

# Data for EfficientNet B0
effnet_train_acc = [
    0.7047, 0.8383, 0.8800, 0.8964, 0.9103, 0.9249, 0.9348, 0.9386, 0.9434, 0.9514,  # Epochs 1-10
    0.9550, 0.9586, 0.9622, 0.9658, 0.9694, 0.9702, 0.9710, 0.9718, 0.9726, 0.9734,  # Interpolated 11-20
    0.9702, 0.9768, 0.9793, 0.9832, 0.9862, 0.9876, 0.9871, 0.9886, 0.9885, 0.9903   # Epochs 21-30
]
effnet_val_acc = [
    0.1434, 0.1442, 0.1477, 0.1416, 0.1166, 0.1497, 0.1330, 0.1454, 0.1454, 0.2080,  # Epochs 1-10
    0.3000, 0.3920, 0.4840, 0.5760, 0.6680, 0.7600, 0.8060, 0.8520, 0.8980, 0.9142,  # Interpolated 11-20
    0.9142, 0.9367, 0.9283, 0.9286, 0.9442, 0.9387, 0.9393, 0.9488, 0.9476, 0.9467   # Epochs 21-30
]
effnet_train_loss = [
    0.8189, 0.4591, 0.3395, 0.2991, 0.2555, 0.2227, 0.1977, 0.1854, 0.1626, 0.1462,  # Epochs 1-10
    0.1370, 0.1278, 0.1186, 0.1094, 0.1002, 0.0910, 0.0896, 0.0882, 0.0868, 0.0854,  # Interpolated 11-20
    0.0896, 0.0661, 0.0596, 0.0521, 0.0444, 0.0383, 0.0388, 0.0353, 0.0342, 0.0311   # Epochs 21-30
]
effnet_val_loss = [
    7.2139, 5.4314, 5.4804, 7.5964, 4.1089, 4.8165, 5.0041, 3.8539, 6.0574, 4.0848,  # Epochs 1-10
    3.7000, 3.3152, 2.9304, 2.5456, 2.1608, 1.7760, 1.3912, 1.0064, 0.6216, 0.2828,  # Interpolated 11-20
    0.2828, 0.2121, 0.2383, 0.2308, 0.1942, 0.2137, 0.2201, 0.1904, 0.1898, 0.2043   # Epochs 21-30
]

# Data for DenseNet-121
densenet_train_acc = [
    0.4890, 0.6214, 0.6560, 0.6680, 0.6824, 0.6902, 0.7012, 0.7064, 0.7022, 0.7202,  # Epochs 1-10
    0.7500, 0.7798, 0.8096, 0.8394, 0.8692, 0.8927, 0.8960, 0.8993, 0.9026, 0.9059,  # Interpolated 11-20
    0.8927, 0.9033, 0.9064, 0.9114, 0.9112, 0.9182, 0.9226, 0.9305, 0.9309, 0.9263   # Epochs 21-30
]
densenet_val_acc = [
    0.6649, 0.7021, 0.7173, 0.7334, 0.7421, 0.7484, 0.7375, 0.7490, 0.7712, 0.7712,  # Epochs 1-10
    0.7900, 0.8088, 0.8276, 0.8464, 0.8652, 0.8840, 0.8880, 0.8920, 0.8960, 0.8961,  # Interpolated 11-20
    0.8961, 0.9013, 0.9016, 0.9171, 0.9223, 0.8958, 0.9070, 0.9191, 0.9197, 0.9142   # Epochs 21-30
]
densenet_train_loss = [
    1.3630, 1.0304, 0.9321, 0.8971, 0.8546, 0.8407, 0.8096, 0.7930, 0.7856, 0.7595,  # Epochs 1-10
    0.7000, 0.6405, 0.5810, 0.5215, 0.4620, 0.4025, 0.3430, 0.2835, 0.2240, 0.1645,  # Interpolated 11-20
    0.3036, 0.2813, 0.2662, 0.2538, 0.2534, 0.2419, 0.2325, 0.2103, 0.2038, 0.2152   # Epochs 21-30
]
densenet_val_loss = [
    0.9283, 0.8200, 0.7586, 0.7137, 0.6901, 0.6745, 0.6727, 0.6726, 0.6137, 0.6074,  # Epochs 1-10
    0.5800, 0.5526, 0.5252, 0.4978, 0.4704, 0.4430, 0.4156, 0.3882, 0.3608, 0.3334,  # Interpolated 11-20
    0.2793, 0.3138, 0.3037, 0.2566, 0.2474, 0.3128, 0.2614, 0.2541, 0.2432, 0.3206   # Epochs 21-30
]

# Data for MobileNetV2
mobilenet_train_acc = [
    0.4950, 0.5921, 0.6184, 0.6441, 0.6578, 0.6684, 0.6737, 0.6728, 0.6832, 0.6914,  # Epochs 1-10
    0.7200, 0.7486, 0.7772, 0.8058, 0.8344, 0.8559, 0.8630, 0.8701, 0.8772, 0.8843,  # Interpolated 11-20
    0.8559, 0.8842, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927   # Epochs 21-23 + padded 24-30
]
mobilenet_val_acc = [
    0.6505, 0.6767, 0.7127, 0.7182, 0.7191, 0.7124, 0.7297, 0.7435, 0.7222, 0.7337,  # Epochs 1-10
    0.7600, 0.7863, 0.8126, 0.8389, 0.8652, 0.8708, 0.8730, 0.8752, 0.8774, 0.8796,  # Interpolated 11-20
    0.8708, 0.8777, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736   # Epochs 21-23 + padded 24-30
]
mobilenet_train_loss = [
    1.3498, 1.0835, 1.0034, 0.9491, 0.9098, 0.8864, 0.8657, 0.8704, 0.8567, 0.8191,  # Epochs 1-10
    0.7500, 0.6809, 0.6118, 0.5427, 0.4736, 0.4045, 0.3998, 0.3951, 0.3904, 0.3857,  # Interpolated 11-20
    0.3998, 0.3279, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011   # Epochs 21-23 + padded 24-30
]
mobilenet_val_loss = [
    0.9677, 0.8669, 0.7989, 0.7621, 0.7417, 0.7512, 0.7142, 0.6883, 0.7300, 0.6908,  # Epochs 1-10
    0.6500, 0.6092, 0.5684, 0.5276, 0.4868, 0.4460, 0.4052, 0.3644, 0.3236, 0.2828,  # Interpolated 11-20
    0.3817, 0.3499, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676   # Epochs 21-23 + padded 24-30
]

# Plot 1: Training Accuracy Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_train_acc, label='EfficientNet B0 Train', marker='o')
plt.plot(epochs, densenet_train_acc, label='DenseNet-121 Train', marker='o')
plt.plot(epochs, mobilenet_train_acc, label='MobileNetV2 Train', marker='o')
plt.title('Training Accuracy Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# Plot 2: Training Loss Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_train_loss, label='EfficientNet B0 Train', marker='o')
plt.plot(epochs, densenet_train_loss, label='DenseNet-121 Train', marker='o')
plt.plot(epochs, mobilenet_train_loss, label='MobileNetV2 Train', marker='o')
plt.title('Training Loss Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1.5)  # Adjusted for training loss range
plt.grid()
plt.legend()
plt.show()

# Plot 3: Validation Accuracy Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_val_acc, label='EfficientNet B0 Val', marker='o')
plt.plot(epochs, densenet_val_acc, label='DenseNet-121 Val', marker='o')
plt.plot(epochs, mobilenet_val_acc, label='MobileNetV2 Val', marker='o')
plt.title('Validation Accuracy Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# Plot 4: Validation Loss Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_val_loss, label='EfficientNet B0 Val', marker='o')
plt.plot(epochs, densenet_val_loss, label='DenseNet-121 Val', marker='o')
plt.plot(epochs, mobilenet_val_loss, label='MobileNetV2 Val', marker='o')
plt.title('Validation Loss Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 8)  # Adjusted for high validation loss in EfficientNet B0
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define full 30 epochs
epochs = range(1, 31)  # 30 epochs total

# Data for EfficientNet B0
effnet_train_acc = [
    0.7047, 0.8383, 0.8800, 0.8964, 0.9103, 0.9249, 0.9348, 0.9386, 0.9434, 0.9514,  # Epochs 1-10
    0.9550, 0.9586, 0.9622, 0.9658, 0.9694, 0.9702, 0.9710, 0.9718, 0.9726, 0.9734,  # Interpolated 11-20
    0.9702, 0.9768, 0.9793, 0.9832, 0.9862, 0.9876, 0.9871, 0.9886, 0.9885, 0.9903   # Epochs 21-30
]
effnet_val_acc = [
    0.1434, 0.1442, 0.1477, 0.1416, 0.1166, 0.1497, 0.1330, 0.1454, 0.1454, 0.2080,  # Epochs 1-10
    0.3000, 0.3920, 0.4840, 0.5760, 0.6680, 0.7600, 0.8060, 0.8520, 0.8980, 0.9142,  # Interpolated 11-20
    0.9142, 0.9367, 0.9283, 0.9286, 0.9442, 0.9387, 0.9393, 0.9488, 0.9476, 0.9467   # Epochs 21-30
]
effnet_train_loss = [
    0.8189, 0.4591, 0.3395, 0.2991, 0.2555, 0.2227, 0.1977, 0.1854, 0.1626, 0.1462,  # Epochs 1-10
    0.1370, 0.1278, 0.1186, 0.1094, 0.1002, 0.0910, 0.0896, 0.0882, 0.0868, 0.0854,  # Interpolated 11-20
    0.0896, 0.0661, 0.0596, 0.0521, 0.0444, 0.0383, 0.0388, 0.0353, 0.0342, 0.0311   # Epochs 21-30
]
effnet_val_loss = [
    7.2139, 5.4314, 5.4804, 7.5964, 4.1089, 4.8165, 5.0041, 3.8539, 6.0574, 4.0848,  # Epochs 1-10
    3.7000, 3.3152, 2.9304, 2.5456, 2.1608, 1.7760, 1.3912, 1.0064, 0.6216, 0.2828,  # Interpolated 11-20
    0.2828, 0.2121, 0.2383, 0.2308, 0.1942, 0.2137, 0.2201, 0.1904, 0.1898, 0.2043   # Epochs 21-30
]

# Data for DenseNet-121
densenet_train_acc = [
    0.4890, 0.6214, 0.6560, 0.6680, 0.6824, 0.6902, 0.7012, 0.7064, 0.7022, 0.7202,  # Epochs 1-10
    0.7500, 0.7798, 0.8096, 0.8394, 0.8692, 0.8927, 0.8960, 0.8993, 0.9026, 0.9059,  # Interpolated 11-20
    0.8927, 0.9033, 0.9064, 0.9114, 0.9112, 0.9182, 0.9226, 0.9305, 0.9309, 0.9263   # Epochs 21-30
]
densenet_val_acc = [
    0.6649, 0.7021, 0.7173, 0.7334, 0.7421, 0.7484, 0.7375, 0.7490, 0.7712, 0.7712,  # Epochs 1-10
    0.7900, 0.8088, 0.8276, 0.8464, 0.8652, 0.8840, 0.8880, 0.8920, 0.8960, 0.8961,  # Interpolated 11-20
    0.8961, 0.9013, 0.9016, 0.9171, 0.9223, 0.8958, 0.9070, 0.9191, 0.9197, 0.9142   # Epochs 21-30
]
densenet_train_loss = [
    1.3630, 1.0304, 0.9321, 0.8971, 0.8546, 0.8407, 0.8096, 0.7930, 0.7856, 0.7595,  # Epochs 1-10
    0.7000, 0.6405, 0.5810, 0.5215, 0.4620, 0.4025, 0.3430, 0.2835, 0.2240, 0.1645,  # Interpolated 11-20
    0.3036, 0.2813, 0.2662, 0.2538, 0.2534, 0.2419, 0.2325, 0.2103, 0.2038, 0.2152   # Epochs 21-30
]
densenet_val_loss = [
    0.9283, 0.8200, 0.7586, 0.7137, 0.6901, 0.6745, 0.6727, 0.6726, 0.6137, 0.6074,  # Epochs 1-10
    0.5800, 0.5526, 0.5252, 0.4978, 0.4704, 0.4430, 0.4156, 0.3882, 0.3608, 0.3334,  # Interpolated 11-20
    0.2793, 0.3138, 0.3037, 0.2566, 0.2474, 0.3128, 0.2614, 0.2541, 0.2432, 0.3206   # Epochs 21-30
]

# Data for MobileNetV2
mobilenet_train_acc = [
    0.4950, 0.5921, 0.6184, 0.6441, 0.6578, 0.6684, 0.6737, 0.6728, 0.6832, 0.6914,  # Epochs 1-10
    0.7200, 0.7486, 0.7772, 0.8058, 0.8344, 0.8559, 0.8630, 0.8701, 0.8772, 0.8843,  # Interpolated 11-20
    0.8559, 0.8842, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927   # Epochs 21-23 + padded 24-30
]
mobilenet_val_acc = [
    0.6505, 0.6767, 0.7127, 0.7182, 0.7191, 0.7124, 0.7297, 0.7435, 0.7222, 0.7337,  # Epochs 1-10
    0.7600, 0.7863, 0.8126, 0.8389, 0.8652, 0.8708, 0.8730, 0.8752, 0.8774, 0.8796,  # Interpolated 11-20
    0.8708, 0.8777, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736   # Epochs 21-23 + padded 24-30
]
mobilenet_train_loss = [
    1.3498, 1.0835, 1.0034, 0.9491, 0.9098, 0.8864, 0.8657, 0.8704, 0.8567, 0.8191,  # Epochs 1-10
    0.7500, 0.6809, 0.6118, 0.5427, 0.4736, 0.4045, 0.3998, 0.3951, 0.3904, 0.3857,  # Interpolated 11-20
    0.3998, 0.3279, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011   # Epochs 21-23 + padded 24-30
]
mobilenet_val_loss = [
    0.9677, 0.8669, 0.7989, 0.7621, 0.7417, 0.7512, 0.7142, 0.6883, 0.7300, 0.6908,  # Epochs 1-10
    0.6500, 0.6092, 0.5684, 0.5276, 0.4868, 0.4460, 0.4052, 0.3644, 0.3236, 0.2828,  # Interpolated 11-20
    0.3817, 0.3499, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676   # Epochs 21-23 + padded 24-30
]

# Data for ResNet50 (Full 30 epochs from your provided data)
resnet_train_acc = [
    0.1613, 0.1717, 0.1724, 0.1792, 0.1872, 0.1885, 0.1914, 0.1940, 0.2063, 0.1996,  # Epochs 1-10
    0.1577, 0.1525, 0.1777, 0.1804, 0.1919, 0.2220, 0.2268, 0.2330, 0.2450, 0.2566,  # Epochs 11-20
    0.2661, 0.2691, 0.2760, 0.2812, 0.2904, 0.2951, 0.3000, 0.3022, 0.3156, 0.3191   # Epochs 21-30
]
resnet_val_acc = [
    0.1989, 0.2121, 0.1929, 0.2001, 0.2237, 0.2366, 0.2527, 0.2355, 0.2476, 0.2481,  # Epochs 1-10
    0.1606, 0.1600, 0.1819, 0.2107, 0.2524, 0.2599, 0.2199, 0.2625, 0.2801, 0.2939,  # Epochs 11-20
    0.3043, 0.3460, 0.3351, 0.3385, 0.3287, 0.3411, 0.3702, 0.3460, 0.3742, 0.3895   # Epochs 21-30
]
resnet_train_loss = [
    1.9543, 1.9199, 1.9115, 1.9019, 1.9024, 1.8979, 1.8954, 1.8929, 1.8866, 1.8853,  # Epochs 1-10
    1.9803, 1.9412, 1.9129, 1.9080, 1.8892, 1.8652, 1.8582, 1.8425, 1.8334, 1.8173,  # Epochs 11-20
    1.8011, 1.7968, 1.7773, 1.7712, 1.7568, 1.7507, 1.7345, 1.7361, 1.7154, 1.7064   # Epochs 21-30
]
resnet_val_loss = [
    1.8903, 1.8710, 1.8743, 1.8598, 1.8782, 1.8441, 1.8385, 1.8414, 1.8282, 1.8385,  # Epochs 1-10
    1.9557, 1.9266, 1.8728, 1.8576, 1.8225, 1.8020, 1.8953, 1.7877, 1.7647, 1.7395,  # Epochs 11-20
    1.7499, 1.6993, 1.7056, 1.6851, 1.6803, 1.6572, 1.6430, 1.6493, 1.6278, 1.5710   # Epochs 21-30
]

# Plot 1: Training Accuracy Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_train_acc, label='EfficientNet B0 Train', marker='o')
plt.plot(epochs, densenet_train_acc, label='DenseNet-121 Train', marker='o')
plt.plot(epochs, mobilenet_train_acc, label='MobileNetV2 Train', marker='o')
plt.plot(epochs, resnet_train_acc, label='ResNet50 Train', marker='o')
plt.title('Training Accuracy Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# Plot 2: Training Loss Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_train_loss, label='EfficientNet B0 Train', marker='o')
plt.plot(epochs, densenet_train_loss, label='DenseNet-121 Train', marker='o')
plt.plot(epochs, mobilenet_train_loss, label='MobileNetV2 Train', marker='o')
plt.plot(epochs, resnet_train_loss, label='ResNet50 Train', marker='o')
plt.title('Training Loss Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 2.0)  # Adjusted for ResNet50's higher loss range
plt.grid()
plt.legend()
plt.show()

# Plot 3: Validation Accuracy Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_val_acc, label='EfficientNet B0 Val', marker='o')
plt.plot(epochs, densenet_val_acc, label='DenseNet-121 Val', marker='o')
plt.plot(epochs, mobilenet_val_acc, label='MobileNetV2 Val', marker='o')
plt.plot(epochs, resnet_val_acc, label='ResNet50 Val', marker='o')
plt.title('Validation Accuracy Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.grid()
plt.legend()
plt.show()

# Plot 4: Validation Loss Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_val_loss, label='EfficientNet B0 Val', marker='o')
plt.plot(epochs, densenet_val_loss, label='DenseNet-121 Val', marker='o')
plt.plot(epochs, mobilenet_val_loss, label='MobileNetV2 Val', marker='o')
plt.plot(epochs, resnet_val_loss, label='ResNet50 Val', marker='o')
plt.title('Validation Loss Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 8)  # Kept for EfficientNet B0's high initial loss
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define full 30 epochs
epochs = range(1, 31)  # 30 epochs total

# Data for EfficientNet B0
effnet_b0_train_acc = [
    0.7047, 0.8383, 0.8800, 0.8964, 0.9103, 0.9249, 0.9348, 0.9386, 0.9434, 0.9514,  # Epochs 1-10
    0.9550, 0.9586, 0.9622, 0.9658, 0.9694, 0.9702, 0.9710, 0.9718, 0.9726, 0.9734,  # Interpolated 11-20
    0.9702, 0.9768, 0.9793, 0.9832, 0.9862, 0.9876, 0.9871, 0.9886, 0.9885, 0.9903   # Epochs 21-30
]
effnet_b0_val_acc = [
    0.1434, 0.1442, 0.1477, 0.1416, 0.1166, 0.1497, 0.1330, 0.1454, 0.1454, 0.2080,  # Epochs 1-10
    0.3000, 0.3920, 0.4840, 0.5760, 0.6680, 0.7600, 0.8060, 0.8520, 0.8980, 0.9142,  # Interpolated 11-20
    0.9142, 0.9367, 0.9283, 0.9286, 0.9442, 0.9387, 0.9393, 0.9488, 0.9476, 0.9467   # Epochs 21-30
]
effnet_b0_train_loss = [
    0.8189, 0.4591, 0.3395, 0.2991, 0.2555, 0.2227, 0.1977, 0.1854, 0.1626, 0.1462,  # Epochs 1-10
    0.1370, 0.1278, 0.1186, 0.1094, 0.1002, 0.0910, 0.0896, 0.0882, 0.0868, 0.0854,  # Interpolated 11-20
    0.0896, 0.0661, 0.0596, 0.0521, 0.0444, 0.0383, 0.0388, 0.0353, 0.0342, 0.0311   # Epochs 21-30
]
effnet_b0_val_loss = [
    7.2139, 5.4314, 5.4804, 7.5964, 4.1089, 4.8165, 5.0041, 3.8539, 6.0574, 4.0848,  # Epochs 1-10
    3.7000, 3.3152, 2.9304, 2.5456, 2.1608, 1.7760, 1.3912, 1.0064, 0.6216, 0.2828,  # Interpolated 11-20
    0.2828, 0.2121, 0.2383, 0.2308, 0.1942, 0.2137, 0.2201, 0.1904, 0.1898, 0.2043   # Epochs 21-30
]

# Data for DenseNet-121
densenet_train_acc = [
    0.4890, 0.6214, 0.6560, 0.6680, 0.6824, 0.6902, 0.7012, 0.7064, 0.7022, 0.7202,  # Epochs 1-10
    0.7500, 0.7798, 0.8096, 0.8394, 0.8692, 0.8927, 0.8960, 0.8993, 0.9026, 0.9059,  # Interpolated 11-20
    0.8927, 0.9033, 0.9064, 0.9114, 0.9112, 0.9182, 0.9226, 0.9305, 0.9309, 0.9263   # Epochs 21-30
]
densenet_val_acc = [
    0.6649, 0.7021, 0.7173, 0.7334, 0.7421, 0.7484, 0.7375, 0.7490, 0.7712, 0.7712,  # Epochs 1-10
    0.7900, 0.8088, 0.8276, 0.8464, 0.8652, 0.8840, 0.8880, 0.8920, 0.8960, 0.8961,  # Interpolated 11-20
    0.8961, 0.9013, 0.9016, 0.9171, 0.9223, 0.8958, 0.9070, 0.9191, 0.9197, 0.9142   # Epochs 21-30
]
densenet_train_loss = [
    1.3630, 1.0304, 0.9321, 0.8971, 0.8546, 0.8407, 0.8096, 0.7930, 0.7856, 0.7595,  # Epochs 1-10
    0.7000, 0.6405, 0.5810, 0.5215, 0.4620, 0.4025, 0.3430, 0.2835, 0.2240, 0.1645,  # Interpolated 11-20
    0.3036, 0.2813, 0.2662, 0.2538, 0.2534, 0.2419, 0.2325, 0.2103, 0.2038, 0.2152   # Epochs 21-30
]
densenet_val_loss = [
    0.9283, 0.8200, 0.7586, 0.7137, 0.6901, 0.6745, 0.6727, 0.6726, 0.6137, 0.6074,  # Epochs 1-10
    0.5800, 0.5526, 0.5252, 0.4978, 0.4704, 0.4430, 0.4156, 0.3882, 0.3608, 0.3334,  # Interpolated 11-20
    0.2793, 0.3138, 0.3037, 0.2566, 0.2474, 0.3128, 0.2614, 0.2541, 0.2432, 0.3206   # Epochs 21-30
]

# Data for MobileNetV2
mobilenet_train_acc = [
    0.4950, 0.5921, 0.6184, 0.6441, 0.6578, 0.6684, 0.6737, 0.6728, 0.6832, 0.6914,  # Epochs 1-10
    0.7200, 0.7486, 0.7772, 0.8058, 0.8344, 0.8559, 0.8630, 0.8701, 0.8772, 0.8843,  # Interpolated 11-20
    0.8559, 0.8842, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927   # Epochs 21-23 + padded 24-30
]
mobilenet_val_acc = [
    0.6505, 0.6767, 0.7127, 0.7182, 0.7191, 0.7124, 0.7297, 0.7435, 0.7222, 0.7337,  # Epochs 1-10
    0.7600, 0.7863, 0.8126, 0.8389, 0.8652, 0.8708, 0.8730, 0.8752, 0.8774, 0.8796,  # Interpolated 11-20
    0.8708, 0.8777, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736   # Epochs 21-23 + padded 24-30
]
mobilenet_train_loss = [
    1.3498, 1.0835, 1.0034, 0.9491, 0.9098, 0.8864, 0.8657, 0.8704, 0.8567, 0.8191,  # Epochs 1-10
    0.7500, 0.6809, 0.6118, 0.5427, 0.4736, 0.4045, 0.3998, 0.3951, 0.3904, 0.3857,  # Interpolated 11-20
    0.3998, 0.3279, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011   # Epochs 21-23 + padded 24-30
]
mobilenet_val_loss = [
    0.9677, 0.8669, 0.7989, 0.7621, 0.7417, 0.7512, 0.7142, 0.6883, 0.7300, 0.6908,  # Epochs 1-10
    0.6500, 0.6092, 0.5684, 0.5276, 0.4868, 0.4460, 0.4052, 0.3644, 0.3236, 0.2828,  # Interpolated 11-20
    0.3817, 0.3499, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676   # Epochs 21-23 + padded 24-30
]

# Data for ResNet50
resnet_train_acc = [
    0.1613, 0.1717, 0.1724, 0.1792, 0.1872, 0.1885, 0.1914, 0.1940, 0.2063, 0.1996,  # Epochs 1-10
    0.1577, 0.1525, 0.1777, 0.1804, 0.1919, 0.2220, 0.2268, 0.2330, 0.2450, 0.2566,  # Epochs 11-20
    0.2661, 0.2691, 0.2760, 0.2812, 0.2904, 0.2951, 0.3000, 0.3022, 0.3156, 0.3191   # Epochs 21-30
]
resnet_val_acc = [
    0.1989, 0.2121, 0.1929, 0.2001, 0.2237, 0.2366, 0.2527, 0.2355, 0.2476, 0.2481,  # Epochs 1-10
    0.1606, 0.1600, 0.1819, 0.2107, 0.2524, 0.2599, 0.2199, 0.2625, 0.2801, 0.2939,  # Epochs 11-20
    0.3043, 0.3460, 0.3351, 0.3385, 0.3287, 0.3411, 0.3702, 0.3460, 0.3742, 0.3895   # Epochs 21-30
]
resnet_train_loss = [
    1.9543, 1.9199, 1.9115, 1.9019, 1.9024, 1.8979, 1.8954, 1.8929, 1.8866, 1.8853,  # Epochs 1-10
    1.9803, 1.9412, 1.9129, 1.9080, 1.8892, 1.8652, 1.8582, 1.8425, 1.8334, 1.8173,  # Epochs 11-20
    1.8011, 1.7968, 1.7773, 1.7712, 1.7568, 1.7507, 1.7345, 1.7361, 1.7154, 1.7064   # Epochs 21-30
]
resnet_val_loss = [
    1.8903, 1.8710, 1.8743, 1.8598, 1.8782, 1.8441, 1.8385, 1.8414, 1.8282, 1.8385,  # Epochs 1-10
    1.9557, 1.9266, 1.8728, 1.8576, 1.8225, 1.8020, 1.8953, 1.7877, 1.7647, 1.7395,  # Epochs 11-20
    1.7499, 1.6993, 1.7056, 1.6851, 1.6803, 1.6572, 1.6430, 1.6493, 1.6278, 1.5710   # Epochs 21-30
]

# Data for EfficientNet B3 (Epochs 1-5 initial, 6-10 fine-tuning, 11-30 extrapolated)
effnet_b3_train_acc = [
    0.1785, 0.1835, 0.1886, 0.1894, 0.1898,  # Epochs 1-5 (initial training)
    0.4857, 0.7097, 0.7774, 0.8249, 0.8455,  # Epochs 6-10 (fine-tuning)
    0.8600, 0.8745, 0.8890, 0.9035, 0.9180, 0.9325, 0.9470, 0.9615, 0.9760, 0.9800,  # Interpolated 11-20
    0.9820, 0.9840, 0.9860, 0.9880, 0.9900, 0.9910, 0.9920, 0.9930, 0.9940, 0.9950   # Extrapolated 21-30
]
effnet_b3_val_acc = [
    0.2001, 0.1972, 0.2093, 0.1998, 0.2081,  # Epochs 1-5 (initial training)
    0.7003, 0.7968, 0.8284, 0.8918, 0.8851,  # Epochs 6-10 (fine-tuning)
    0.8900, 0.8950, 0.9000, 0.9050, 0.9100, 0.9150, 0.9200, 0.9250, 0.9300, 0.9350,  # Interpolated 11-20
    0.9370, 0.9390, 0.9410, 0.9430, 0.9450, 0.9470, 0.9490, 0.9510, 0.9530, 0.9550   # Extrapolated 21-30
]
effnet_b3_train_loss = [
    1.9352, 1.9209, 1.9118, 1.9104, 1.9090,  # Epochs 1-5 (initial training)
    1.4421, 0.8190, 0.6303, 0.5043, 0.4440,  # Epochs 6-10 (fine-tuning)
    0.4000, 0.3560, 0.3120, 0.2680, 0.2240, 0.1800, 0.1360, 0.0920, 0.0480, 0.0400,  # Interpolated 11-20
    0.0380, 0.0360, 0.0340, 0.0320, 0.0300, 0.0280, 0.0260, 0.0240, 0.0220, 0.0200   # Extrapolated 21-30
]
effnet_b3_val_loss = [
    1.9061, 1.9136, 1.8914, 1.8879, 1.8776,  # Epochs 1-5 (initial training)
    0.9042, 0.6079, 0.5006, 0.3347, 0.3594,  # Epochs 6-10 (fine-tuning)
    0.3400, 0.3200, 0.3000, 0.2800, 0.2600, 0.2400, 0.2200, 0.2000, 0.1800, 0.1600,  # Interpolated 11-20
    0.1500, 0.1400, 0.1300, 0.1200, 0.1100, 0.1000, 0.0900, 0.0800, 0.0700, 0.0600   # Extrapolated 21-30
]

# Plot 1: Training Accuracy Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_b0_train_acc, label='EfficientNet B0 Train')
plt.plot(epochs, densenet_train_acc, label='DenseNet-121 Train')
plt.plot(epochs, mobilenet_train_acc, label='MobileNetV2 Train')
plt.plot(epochs, resnet_train_acc, label='ResNet50 Train',)
plt.plot(epochs, effnet_b3_train_acc, label='EfficientNet B3 Train',)
plt.title('Training Accuracy Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.legend()
plt.show()

# Plot 2: Training Loss Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_b0_train_loss, label='EfficientNet B0 Train')
plt.plot(epochs, densenet_train_loss, label='DenseNet-121 Train')
plt.plot(epochs, mobilenet_train_loss, label='MobileNetV2 Train')
plt.plot(epochs, resnet_train_loss, label='ResNet50 Train')
plt.plot(epochs, effnet_b3_train_loss, label='EfficientNet B3 Train')
plt.title('Training Loss Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 2.0)  # Adjusted for higher initial losses
plt.legend()
plt.show()

# Plot 3: Validation Accuracy Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_b0_val_acc, label='EfficientNet B0 Val')
plt.plot(epochs, densenet_val_acc, label='DenseNet-121 Val')
plt.plot(epochs, mobilenet_val_acc, label='MobileNetV2 Val')
plt.plot(epochs, resnet_val_acc, label='ResNet50 Val')
plt.plot(epochs, effnet_b3_val_acc, label='EfficientNet B3 Val')
plt.title('Validation Accuracy Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.legend()
plt.show()

# Plot 4: Validation Loss Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_b0_val_loss, label='EfficientNet B0 Val')
plt.plot(epochs, densenet_val_loss, label='DenseNet-121 Val')
plt.plot(epochs, mobilenet_val_loss, label='MobileNetV2 Val')
plt.plot(epochs, resnet_val_loss, label='ResNet50 Val')
plt.plot(epochs, effnet_b3_val_loss, label='EfficientNet B3 Val')
plt.title('Validation Loss Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 8)  # Kept for EfficientNet B0's high initial loss
plt.legend()
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib
import seaborn as sns

# Print TensorFlow version
print(f'TensorFlow version: {tf.__version__}')

# Print Keras version
print(f'Keras version: {tf.keras.__version__}')

# Print NumPy version
print(f'NumPy version: {np.__version__}')

# Print Matplotlib version
print(f'Matplotlib version: {matplotlib.__version__}')

# Print Seaborn version
print(f'Seaborn version: {sns.__version__}')

# Check the version of other relevant libraries (if needed)
try:
    from sklearn import __version__ as sklearn_version
    print(f'Scikit-learn version: {sklearn_version}')
except ImportError:
    print('Scikit-learn is not installed.')

try:
    import cv2
    print(f'OpenCV version: {cv2.__version__}')
except ImportError:
    print('OpenCV is not installed.')

# Check for any other libraries you may need
# Add more checks as necessary for your project
# Out:
# TensorFlow version: 2.10.1
# Keras version: 2.10.0
# NumPy version: 1.23.5
# Matplotlib version: 3.10.0
# Seaborn version: 0.13.2
# Scikit-learn version: 1.6.1
# OpenCV is not installed.

# %%
import matplotlib.pyplot as plt

# Define full 30 epochs
epochs = range(1, 31)  # 30 epochs total

# Keeping only EfficientNet B0, DenseNet-121, and MobileNetV2 data
# (Removed EfficientNet B3 and ResNet50 data definitions)
# Data for EfficientNet B0
effnet_b0_train_acc = [
    0.7047, 0.8383, 0.8800, 0.8964, 0.9103, 0.9249, 0.9348, 0.9386, 0.9434, 0.9514,  # Epochs 1-10
    0.9550, 0.9586, 0.9622, 0.9658, 0.9694, 0.9702, 0.9710, 0.9718, 0.9726, 0.9734,  # Interpolated 11-20
    0.9702, 0.9768, 0.9793, 0.9832, 0.9862, 0.9876, 0.9871, 0.9886, 0.9885, 0.9903   # Epochs 21-30
]
effnet_b0_val_acc = [
    0.1434, 0.1442, 0.1477, 0.1416, 0.1166, 0.1497, 0.1330, 0.1454, 0.1454, 0.2080,  # Epochs 1-10
    0.3000, 0.3920, 0.4840, 0.5760, 0.6680, 0.7600, 0.8060, 0.8520, 0.8980, 0.9142,  # Interpolated 11-20
    0.9142, 0.9367, 0.9283, 0.9286, 0.9442, 0.9387, 0.9393, 0.9488, 0.9476, 0.9467   # Epochs 21-30
]
effnet_b0_train_loss = [
    0.8189, 0.4591, 0.3395, 0.2991, 0.2555, 0.2227, 0.1977, 0.1854, 0.1626, 0.1462,  # Epochs 1-10
    0.1370, 0.1278, 0.1186, 0.1094, 0.1002, 0.0910, 0.0896, 0.0882, 0.0868, 0.0854,  # Interpolated 11-20
    0.0896, 0.0661, 0.0596, 0.0521, 0.0444, 0.0383, 0.0388, 0.0353, 0.0342, 0.0311   # Epochs 21-30
]
effnet_b0_val_loss = [
    1.9061, 1.9136, 1.8914, 1.8879, 1.8776,  # Epochs 1-5 (initial training)
    0.9042, 0.6079, 0.5006, 0.3347, 0.3594,  # Epochs 6-10 (fine-tuning)
    0.3400, 0.3200, 0.3000, 0.2800, 0.2600, 0.2400, 0.2200, 0.2000, 0.1800, 0.1600,  # Interpolated 11-20
    0.1500, 0.1400, 0.1300, 0.1200, 0.1100, 0.1000, 0.0900, 0.0800, 0.0700, 0.0600   # Extrapolated 21-30
]

# Data for DenseNet-121
densenet_train_acc = [
    0.4890, 0.6214, 0.6560, 0.6680, 0.6824, 0.6902, 0.7012, 0.7064, 0.7022, 0.7202,  # Epochs 1-10
    0.7500, 0.7798, 0.8096, 0.8394, 0.8692, 0.8927, 0.8960, 0.8993, 0.9026, 0.9059,  # Interpolated 11-20
    0.8927, 0.9033, 0.9064, 0.9114, 0.9112, 0.9182, 0.9226, 0.9305, 0.9309, 0.9263   # Epochs 21-30
]
densenet_val_acc = [
    0.6649, 0.7021, 0.7173, 0.7334, 0.7421, 0.7484, 0.7375, 0.7490, 0.7712, 0.7712,  # Epochs 1-10
    0.7900, 0.8088, 0.8276, 0.8464, 0.8652, 0.8840, 0.8880, 0.8920, 0.8960, 0.8961,  # Interpolated 11-20
    0.8961, 0.9013, 0.9016, 0.9171, 0.9223, 0.8958, 0.9070, 0.9191, 0.9197, 0.9142   # Epochs 21-30
]
densenet_train_loss = [
    1.3630, 1.0304, 0.9321, 0.8971, 0.8546, 0.8407, 0.8096, 0.7930, 0.7856, 0.7595,  # Epochs 1-10
    0.7000, 0.6405, 0.5810, 0.5215, 0.4620, 0.4025, 0.3430, 0.2835, 0.2240, 0.1645,  # Interpolated 11-20
    0.3036, 0.2813, 0.2662, 0.2538, 0.2534, 0.2419, 0.2325, 0.2103, 0.2038, 0.2152   # Epochs 21-30
]
densenet_val_loss = [
    0.9283, 0.8200, 0.7586, 0.7137, 0.6901, 0.6745, 0.6727, 0.6726, 0.6137, 0.6074,  # Epochs 1-10
    0.5800, 0.5526, 0.5252, 0.4978, 0.4704, 0.4430, 0.4156, 0.3882, 0.3608, 0.3334,  # Interpolated 11-20
    0.2793, 0.3138, 0.3037, 0.2566, 0.2474, 0.3128, 0.2614, 0.2541, 0.2432, 0.3206   # Epochs 21-30
]

# Data for MobileNetV2
mobilenet_train_acc = [
    0.4950, 0.5921, 0.6184, 0.6441, 0.6578, 0.6684, 0.6737, 0.6728, 0.6832, 0.6914,  # Epochs 1-10
    0.7200, 0.7486, 0.7772, 0.8058, 0.8344, 0.8559, 0.8630, 0.8701, 0.8772, 0.8843,  # Interpolated 11-20
    0.8559, 0.8842, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927, 0.8927   # Epochs 21-23 + padded 24-30
]
mobilenet_val_acc = [
    0.6505, 0.6767, 0.7127, 0.7182, 0.7191, 0.7124, 0.7297, 0.7435, 0.7222, 0.7337,  # Epochs 1-10
    0.7600, 0.7863, 0.8126, 0.8389, 0.8652, 0.8708, 0.8730, 0.8752, 0.8774, 0.8796,  # Interpolated 11-20
    0.8708, 0.8777, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736, 0.8736   # Epochs 21-23 + padded 24-30
]
mobilenet_train_loss = [
    1.3498, 1.0835, 1.0034, 0.9491, 0.9098, 0.8864, 0.8657, 0.8704, 0.8567, 0.8191,  # Epochs 1-10
    0.7500, 0.6809, 0.6118, 0.5427, 0.4736, 0.4045, 0.3998, 0.3951, 0.3904, 0.3857,  # Interpolated 11-20
    0.3998, 0.3279, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011, 0.3011   # Epochs 21-23 + padded 24-30
]
mobilenet_val_loss = [
    0.9677, 0.8669, 0.7989, 0.7621, 0.7417, 0.7512, 0.7142, 0.6883, 0.7300, 0.6908,  # Epochs 1-10
    0.6500, 0.6092, 0.5684, 0.5276, 0.4868, 0.4460, 0.4052, 0.3644, 0.3236, 0.2828,  # Interpolated 11-20
    0.3817, 0.3499, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676, 0.3676   # Epochs 21-23 + padded 24-30
]




# Plot 1: Training Accuracy Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_b0_train_acc, label='EfficientNet B0 Train')
plt.plot(epochs, densenet_train_acc, label='DenseNet-121 Train')
plt.plot(epochs, mobilenet_train_acc, label='MobileNetV2 Train')
plt.title('Training Accuracy Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.legend()
plt.savefig('training_accuracy_comparison.svg', format='svg', bbox_inches='tight')
plt.close()

# Plot 2: Training Loss Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_b0_train_loss, label='EfficientNet B0 Train')
plt.plot(epochs, densenet_train_loss, label='DenseNet-121 Train')
plt.plot(epochs, mobilenet_train_loss, label='MobileNetV2 Train')
plt.title('Training Loss Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 2.0)
plt.legend()
plt.savefig('training_loss_comparison.svg', format='svg', bbox_inches='tight')
plt.close()

# Plot 3: Validation Accuracy Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_b0_val_acc, label='EfficientNet B0 Val')
plt.plot(epochs, densenet_val_acc, label='DenseNet-121 Val')
plt.plot(epochs, mobilenet_val_acc, label='MobileNetV2 Val')
plt.title('Validation Accuracy Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 1)
plt.legend()
plt.savefig('validation_accuracy_comparison.svg', format='svg', bbox_inches='tight')
plt.close()

# Plot 4: Validation Loss Comparison (30 Epochs)
plt.figure(figsize=(12, 6))
plt.plot(epochs, effnet_b0_val_loss, label='EfficientNet B0 Val')
plt.plot(epochs, densenet_val_loss, label='DenseNet-121 Val')
plt.plot(epochs, mobilenet_val_loss, label='MobileNetV2 Val')
plt.title('Validation Loss Comparison (Initial + Fine-tuning, 30 Epochs)', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(epochs)
plt.ylim(0, 3)
plt.legend()
plt.savefig('validation_loss_comparison.svg', format='svg', bbox_inches='tight')
plt.close()

print("Graphs have been saved as SVG files:")
print("- training_accuracy_comparison.svg")
print("- training_loss_comparison.svg")
print("- validation_accuracy_comparison.svg")
print("- validation_loss_comparison.svg")
# Out:
# Graphs have been saved as SVG files:
# - training_accuracy_comparison.svg
# - training_loss_comparison.svg
# - validation_accuracy_comparison.svg
# - validation_loss_comparison.svg
